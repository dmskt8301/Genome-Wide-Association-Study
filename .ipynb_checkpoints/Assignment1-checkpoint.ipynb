# %%
# %run datasetGenerator.py --ID 1002104402

# %%
import csv
import numpy as np
import pandas as pd
from scipy.stats import fisher_exact
odd_ratios=[]
p_values=[]
with open("1002104402.csv", 'r') as file:
    reader = csv.reader(file,delimiter='\t')
    header=next(reader)
    for row in reader:
        x = row[0].split(",")
        y=np.resize(np.array([list(map(float, x[1:]))]),(2,2))
        oddsr, p = fisher_exact(y, alternative='greater')
        odd_ratios.append(oddsr)
        p_values.append(p)
df = pd.read_csv("1002104402.csv")
df["odd_ratios"] = odd_ratios
df["p_values"]=p_values
df.to_csv("1002104402.csv", index=False)

# %%
df
# Out:
#         SNP  Case_Num_C_Allele  Case_Num_T_Allele  Control_Num_C_Allele  \
# 0      snp0                 21                 29                    33
# 1      snp1                 33                 17                    10
# 2      snp2                 44                  6                    50
# 3      snp3                 44                  6                    67
# 4      snp4                  5                 45                    69
# ..      ...                ...                ...                   ...
# 995  snp995                  1                 49                    79
# 996  snp996                 12                 38                    42
# 997  snp997                 49                  1                    47
# 998  snp998                 23                 27                     6
# 999  snp999                 16                 34                    31
#
#      Control_Num_T_Allele  odd_ratios      p_values
# 0                      67    1.470219  1.832541e-01
# 1                      90   17.470588  2.337927e-12
# 2                      50    7.333333  2.484441e-06
# 3                      33    3.611940  3.907805e-03
# 4                      31    0.049919  1.000000e+00
# ..                    ...         ...           ...
# 995                    21    0.005425  1.000000e+00
# 996                    58    0.436090  9.914473e-01
# 997                    53   55.255319  1.720569e-11
# 998                    94   13.345679  1.734401e-08
# 999                    69    1.047438  5.216624e-01
#
# [1000 rows x 7 columns]

# %%
result = pd.DataFrame(df[['SNP', 'p_values']])
result
# Out:
#         SNP      p_values
# 0      snp0  1.832541e-01
# 1      snp1  2.337927e-12
# 2      snp2  2.484441e-06
# 3      snp3  3.907805e-03
# 4      snp4  1.000000e+00
# ..      ...           ...
# 995  snp995  1.000000e+00
# 996  snp996  9.914473e-01
# 997  snp997  1.720569e-11
# 998  snp998  1.734401e-08
# 999  snp999  5.216624e-01
#
# [1000 rows x 2 columns]

# %%
result = result.assign(significant= df['p_values']<5e-8)
result
# Out:
#         SNP      p_values  significant
# 0      snp0  1.832541e-01        False
# 1      snp1  2.337927e-12         True
# 2      snp2  2.484441e-06        False
# 3      snp3  3.907805e-03        False
# 4      snp4  1.000000e+00        False
# ..      ...           ...          ...
# 995  snp995  1.000000e+00        False
# 996  snp996  9.914473e-01        False
# 997  snp997  1.720569e-11         True
# 998  snp998  1.734401e-08         True
# 999  snp999  5.216624e-01        False
#
# [1000 rows x 3 columns]

# %%
result['significant'].value_counts() [True]
# Out:
# 166

# %%
result
# Out:
#         SNP      p_values  significant
# 0      snp0  1.832541e-01        False
# 1      snp1  2.337927e-12         True
# 2      snp2  2.484441e-06        False
# 3      snp3  3.907805e-03        False
# 4      snp4  1.000000e+00        False
# ..      ...           ...          ...
# 995  snp995  1.000000e+00        False
# 996  snp996  9.914473e-01        False
# 997  snp997  1.720569e-11         True
# 998  snp998  1.734401e-08         True
# 999  snp999  5.216624e-01        False
#
# [1000 rows x 3 columns]

# %%
result.to_csv("res.csv", index=False)

# %%
result = result.assign(significant_after_corrected= df['p_values']<5e-11)
result
# Out:
#         SNP      p_values  significant  significant_after_corrected
# 0      snp0  1.832541e-01        False                        False
# 1      snp1  2.337927e-12         True                         True
# 2      snp2  2.484441e-06        False                        False
# 3      snp3  3.907805e-03        False                        False
# 4      snp4  1.000000e+00        False                        False
# ..      ...           ...          ...                          ...
# 995  snp995  1.000000e+00        False                        False
# 996  snp996  9.914473e-01        False                        False
# 997  snp997  1.720569e-11         True                         True
# 998  snp998  1.734401e-08         True                        False
# 999  snp999  5.216624e-01        False                        False
#
# [1000 rows x 4 columns]

# %%
result.to_csv("significant_after_corrected.csv", index=False)

# %%
result['significant_after_corrected'].value_counts() [True]
# Out:
# 114

# %%
from pandas import DataFrame
from scipy.stats import uniform
from scipy.stats import randint
import numpy as np
import matplotlib.pyplot as plt

# -log_10(pvalue)
df['minuslog10pvalue'] = -np.log10(df.p_values)

# How to plot SNP vs. -log10(pvalue)?
df['SNP'] = range(len(df))
df_grouped = df.groupby(('SNP'))

fig = plt.figure()
ax = fig.add_subplot(111)
for num, (name, group) in enumerate(df_grouped):
    group.plot(kind='scatter', x='SNP', y='minuslog10pvalue', ax=ax, color='black')
    
#original threshold
plt.axhline(y = 8, color = 'b')
#corrected threshold
plt.axhline(y = 11, color = 'r')
ax.set_xlim([0, len(df.p_values)])
ax.set_ylim([0, 40])
ax.set_xlabel('SNP')
# Out:
# Text(0.5, 0, 'SNP')
